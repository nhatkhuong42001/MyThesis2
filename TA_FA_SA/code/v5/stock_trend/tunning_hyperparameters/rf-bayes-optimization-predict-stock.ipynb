# %%
pip install optuna
# Out:
# Requirement already satisfied: optuna in /usr/local/lib/python3.11/dist-packages (4.3.0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (1.15.2)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.11/dist-packages (from optuna) (6.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (25.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.40)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (1.3.10)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.13.2)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.1.1)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->optuna) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->optuna) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->optuna) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->optuna) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->optuna) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->optuna) (2.4.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.11/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.2)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->optuna) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->optuna) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->optuna) (1.3.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->optuna) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->optuna) (2024.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install ta
# Out:
# Collecting ta
#   Downloading ta-0.11.0.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from ta) (1.26.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from ta) (2.2.3)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->ta) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->ta) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->ta) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->ta) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->ta) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->ta) (2.4.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->ta) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->ta) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->ta) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->ta) (1.17.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->ta) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->ta) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->ta) (1.3.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->ta) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->ta) (2024.2.0)
# Building wheels for collected packages: ta
#   Building wheel for ta (setup.py) ... done
#   Created wheel for ta: filename=ta-0.11.0-py3-none-any.whl size=29412 sha256=8c67a42cf017c29eb288cb8b39473dd14c8586ed2f4af36eee92256fbc9c060b
#   Stored in directory: /root/.cache/pip/wheels/a1/d7/29/7781cc5eb9a3659d032d7d15bdd0f49d07d2b24fec29f44bc4
# Successfully built ta
# Installing collected packages: ta
# Successfully installed ta-0.11.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.0.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.13.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.72.0rc1)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (14.0.0)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.14.1)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy<2.1.0,>=1.26.0->tensorflow) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy<2.1.0,>=1.26.0->tensorflow) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy<2.1.0,>=1.26.0->tensorflow) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy<2.1.0,>=1.26.0->tensorflow) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy<2.1.0,>=1.26.0->tensorflow) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy<2.1.0,>=1.26.0->tensorflow) (2.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.4.26)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy<2.1.0,>=1.26.0->tensorflow) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy<2.1.0,>=1.26.0->tensorflow) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy<2.1.0,>=1.26.0->tensorflow) (1.3.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy<2.1.0,>=1.26.0->tensorflow) (2024.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.19.1)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy<2.1.0,>=1.26.0->tensorflow) (2024.2.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install keras-tuner
# Out:
# Requirement already satisfied: keras-tuner in /usr/local/lib/python3.11/dist-packages (1.4.7)
# Requirement already satisfied: keras in /usr/local/lib/python3.11/dist-packages (from keras-tuner) (3.8.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from keras-tuner) (25.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from keras-tuner) (2.32.3)
# Requirement already satisfied: kt-legacy in /usr/local/lib/python3.11/dist-packages (from keras-tuner) (1.0.5)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from keras->keras-tuner) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from keras->keras-tuner) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras->keras-tuner) (14.0.0)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras->keras-tuner) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.11/dist-packages (from keras->keras-tuner) (3.13.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras->keras-tuner) (0.14.1)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.11/dist-packages (from keras->keras-tuner) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->keras-tuner) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->keras-tuner) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->keras-tuner) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->keras-tuner) (2025.4.26)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->keras->keras-tuner) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->keras->keras-tuner) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->keras->keras-tuner) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->keras->keras-tuner) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->keras->keras-tuner) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->keras->keras-tuner) (2.4.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from optree->keras->keras-tuner) (4.13.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras->keras-tuner) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras->keras-tuner) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras->keras-tuner) (0.1.2)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->keras->keras-tuner) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->keras->keras-tuner) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->keras->keras-tuner) (1.3.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->keras->keras-tuner) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->keras->keras-tuner) (2024.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import RobustScaler
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dropout, Dense, RNN, concatenate
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.layers import Layer
import tensorflow as tf
from keras.layers import Input, Conv1D, MaxPooling1D, Bidirectional, Flatten, BatchNormalization
from sklearn.model_selection import RandomizedSearchCV
# from scikeras.wrappers import KerasClassifier


from sklearn.preprocessing import StandardScaler
from tensorflow.keras.regularizers import l2
from tensorflow.keras.regularizers import l1
from tensorflow.keras.regularizers import l1_l2
from tensorflow.keras import regularizers
from tensorflow.keras.models import Model
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import roc_auc_score
import keras_tuner as kt
from tensorflow.keras.optimizers import Adam
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.base import BaseEstimator, ClassifierMixin
from tensorflow.keras.saving import register_keras_serializable
import matplotlib.pyplot as plt
# from imblearn.over_sampling import SMOTE
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from sklearn.metrics import f1_score
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from sklearn.model_selection import cross_val_score
import pandas as pd
import os
from collections import Counter
from tensorflow.keras.models import load_model
from sklearn.metrics import classification_report
from sklearn.utils.class_weight import compute_class_weight
from sklearn.ensemble import RandomForestClassifier # Import RandomForestClassifier
from sklearn.metrics import accuracy_score # Import accuracy
from sklearn.metrics import log_loss
from sklearn.linear_model import LinearRegression
from xgboost import XGBClassifier
import optuna
import joblib
from sklearn.metrics import (
    f1_score, accuracy_score, classification_report, roc_auc_score,
    roc_curve, auc
)
from sklearn.preprocessing import label_binarize
from sklearn.model_selection import TimeSeriesSplit

# %%
pip install xgboost
# Out:
# Requirement already satisfied: xgboost in /usr/local/lib/python3.11/dist-packages (2.0.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from xgboost) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from xgboost) (1.15.2)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->xgboost) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->xgboost) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->xgboost) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->xgboost) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->xgboost) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->xgboost) (2.4.1)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->xgboost) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->xgboost) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->xgboost) (1.3.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->xgboost) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->xgboost) (2024.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
def dataframe_to_x_y(df, feature, target):
  X_train, y_train = [], []
  X_val, y_val = [], []
  n = len(df)
  split_index = int(n * 0.8)
  X_train = df[feature][:split_index]
  y_train = df[target][:split_index]
  X_val = df[feature][split_index:]
  y_val = df[target][split_index:]
  return X_train, y_train, X_val, y_val

# %%
sentiment_columns = [
        'Reputation', 'Company Communication', 'Appointment', 'Financial', 'Regulatory',
        'Sales', 'M&A', 'Legal', 'Dividend Policy', 'Risks', 'Rumors', 'Strategy',
        'Options', 'IPO', 'Signal', 'Coverage', 'Fundamentals', 'Insider Activity',
        'Price Action', 'Buyside', 'Technical Analysis', 'Trade', 'Central Banks',
        'Currency', 'Conditions', 'Market', 'Volatility', 'Investor Sentiment', 'Retail Investor Behavior',
        'Speculation', 'Domestic Institutional Behavior', 'Foreign Institutional Behavior', 'Black Swan Event',
    ]

sentiment_p1d_columns = [
        'reputation_p1d', 'company_communication_p1d', 'appointment_p1d', 'financial_p1d', 'regulatory_p1d',
        'sales_p1d', 'm&a_p1d', 'legal_p1d', 'dividend_policy_p1d', 'risks_p1d', 'rumors_p1d', 'strategy_p1d',
        'options_p1d', 'ipo_p1d', 'signal_p1d', 'coverage_p1d', 'fundamentals_p1d', 'insider_activity_p1d',
        'price_action_p1d', 'buyside_p1d', 'technical_analysis_p1d', 'trade_p1d', 'central_banks_p1d',
        'currency_p1d', 'conditions_p1d', 'market_p1d', 'volatility_p1d', 'investor_sentiment_p1d', 'retail_investor_behavior_p1d',
        'speculation_p1d', 'domestic_institutional_behavior_p1d', 'foreign_institutional_behavior_p1d', 'black_swan_event_p1d',
    ]
meta_cols = ['num_sa_news', 'mean_sentiment_norm', 'max_sentiment_norm', 'std_sentiment_score', 'sum_positive_sa', 'sum_negative_sa', 'time_distance_from_sa_to_close_minutes']
meta_p1d_cols = ['num_sa_news_p1d', 'mean_sentiment_norm_p1d', 'max_sentiment_norm_p1d', 'std_sentiment_score_p1d', 'sum_positive_sa_p1d', 'sum_negative_sa_p1d', 'time_distance_from_sa_to_close_minutes_p1d']

sentiment_feature_selected =  sentiment_columns + sentiment_p1d_columns + meta_cols + meta_p1d_cols
ta_features = ['volume_ma','volume_to_volume_ma_ratio','ema_12','ema_26','sma_20','sma_50','roc_5','roc_1','roc_9','%K','%R','cci','obv','macd','signal_line','macd_histogram','rsi','rsi_base_ma','rsi_rsi_base_ma_ratio','bb_bbm','bb_bbh','bb_bbl','bb_bbp','bb_bbh_bb_bbl_ratio','hl_ratio', 'co_ratio', 'price_range', 'sma_ratio_20_50', 'ema_ratio_12_26', 'bb_width', 'bb_position', 'rsi_overbought', 'rsi_oversold', 'rsi_neutral', 'macd_bullish', 'momentum_5', 'momentum_10','log_return','volatility_5d','volatility_10d','volatility_20d','volatility_30d','mean_log_return_5d','mean_log_return_10d','mean_log_return_20d','mean_log_return_30d','sharpe_like_5d','sharpe_like_10d','sharpe_like_20d','sharpe_like_30d','up_streak','pos_log_return_ratio_20d','z_score_5d','z_score_10d','z_score_20d','z_score_30d','annual_return','daily_return','sharpe_ratio',
               'rsi_vn30','rsi_base_ma_vn30','rsi_rsi_base_ma_ratio_vn30','volume_ma_vn30','volume_to_volume_ma_ratio_vn30','bb_bbm_vn30','bb_bbh_vn30','bb_bbl_vn30','bb_bbp_vn30','bb_bbh_bb_bbl_ratio_vn30','roc_1_vn30', 'roc_5_vn30', 'roc_9_vn30','%K_vn30','%R_vn30','cci_vn30','obv_vn30','ema_12_vn30','ema_26_vn30','sma_20_vn30','sma_50_vn30', 'hl_ratio_vn30', 'co_ratio_vn30', 'price_range_vn30', 'sma_ratio_20_50_vn30', 'ema_ratio_12_26_vn30', 'bb_width_vn30', 'bb_position_vn30', 'rsi_overbought_vn30', 'rsi_oversold_vn30', 'rsi_neutral_vn30', 'momentum_5_vn30', 'momentum_10_vn30', 'log_return_vn30','volatility_5d_vn30','volatility_10d_vn30','volatility_20d_vn30','volatility_30d_vn30','mean_log_return_5d_vn30','mean_log_return_10d_vn30','mean_log_return_20d_vn30','mean_log_return_30d_vn30','sharpe_like_5d_vn30','sharpe_like_10d_vn30','sharpe_like_20d_vn30','sharpe_like_30d_vn30','up_streak_vn30','pos_log_return_ratio_20d_vn30','z_score_5d_vn30','z_score_10d_vn30','z_score_20d_vn30','z_score_30d_vn30','annual_return_vn30','daily_return_vn30','sharpe_ratio_vn30',
               'rsi_vni','rsi_base_ma_vni','rsi_rsi_base_ma_ratio_vni','volume_ma_vni','volume_to_volume_ma_ratio_vni','bb_bbm_vni','bb_bbh_vni','bb_bbl_vni','bb_bbp_vni','bb_bbh_bb_bbl_ratio_vni','roc_1_vni', 'roc_5_vni', 'roc_9_vni','%K_vni','%R_vni','cci_vni','obv_vni','ema_12_vni','ema_26_vni','sma_20_vni','sma_50_vni', 'hl_ratio_vni', 'co_ratio_vni', 'price_range_vni', 'sma_ratio_20_50_vni', 'ema_ratio_12_26_vni', 'bb_width_vni', 'bb_position_vni', 'rsi_overbought_vni', 'rsi_oversold_vni', 'rsi_neutral_vni', 'momentum_5_vni', 'momentum_10_vni','log_return_vni','volatility_5d_vni','volatility_10d_vni','volatility_20d_vni','volatility_30d_vni','mean_log_return_5d_vni','mean_log_return_10d_vni','mean_log_return_20d_vni','mean_log_return_30d_vni','sharpe_like_5d_vni','sharpe_like_10d_vni','sharpe_like_20d_vni','sharpe_like_30d_vni','up_streak_vni','pos_log_return_ratio_20d_vni','z_score_5d_vni','z_score_10d_vni','z_score_20d_vni','z_score_30d_vni','annual_return_vni','daily_return_vni','sharpe_ratio_vni']
fa_features = ['p/b_previous_quarter', 'p/b_change_rate','p/b_change_rate_flag','p/e_previous_quarter','p/e_change_rate','p/e_change_rate_flag','p/s_previous_quarter','p/s_change_rate','p/s_change_rate_flag','p/cash_flow_previous_quarter','p/cash_flow_change_rate','p/cash_flow_change_rate_flag','eps_previous_quarter','eps_change_rate', 'eps_change_rate_flag','bvps_previous_quarter','bvps_change_rate', 'bvps_change_rate_flag','roe_previous_quarter','roe_change_rate','roe_change_rate_flag','roa_previous_quarter','roa_change_rate','roa_change_rate_flag','coefficient_p/b','coefficient_p/e','coefficient_p/s','coefficient_p/cash_flow','coefficient_eps','coefficient_bvps','coefficient_roe','coefficient_roa','distance_to_nearest_quarter']
ta_fa_feature_selected = ta_features + fa_features
features = ta_fa_feature_selected + sentiment_feature_selected
target = 'target'
scaler = StandardScaler()

# %%
def load_data_for_analysis(tickers, folder_path):

    df_all = []

    for ticker in tickers:
        file_path = os.path.join(folder_path, f"{ticker}.xlsx")
        if os.path.exists(file_path):
            df = pd.read_excel(file_path)
            df["ticker"] = ticker  # thêm cột ticker
            df_all.append(df)
        else:
            print(f"⚠️ Không tìm thấy: {file_path}")

    # Gộp lại thành 1 DataFrame
    df_global = pd.concat(df_all, ignore_index=True)
    print(f"✅ Đã load xong {len(df_global)} dòng dữ liệu từ {len(df_all)} cổ phiếu.")
    return df_global

# %%
tickers = ['ACB', 'BCM', 'BID','BVH','CTG','FPT','GAS','GVR','HDB','HPG',
                    'LPB','MBB','MSN','MWG','PLX','SAB','SHB','SSB','SSI','STB',
                    'TCB','TPB','VCB','VHM','VIB','VIC','VJC','VNM','VPB','VRE']
folder_path_train = "/kaggle/input/vn30-dataset/v6 - Copy/stock_trend/train_data" 
folder_path_test = "/kaggle/input/vn30-dataset/v6 - Copy/stock_trend/test_data" 
df_global_train = load_data_for_analysis(tickers, folder_path_train)
df_global_test = load_data_for_analysis(tickers, folder_path_test)
# Out:
# ✅ Đã load xong 35865 dòng dữ liệu từ 30 cổ phiếu.
# ✅ Đã load xong 7380 dòng dữ liệu từ 30 cổ phiếu.

# %%
# Danh sách các mô hình
models = {
    "Random Forest": RandomForestClassifier(n_jobs=-1, random_state=42, class_weight='balanced'),
    "XGBoost": XGBClassifier(n_jobs=-1, random_state=42, use_label_encoder=False, eval_metric='mlogloss'),
    "LightGBM": LGBMClassifier(n_jobs=-1, random_state=42),
    "CatBoost": CatBoostClassifier(verbose=0, random_state=42),
    "AdaBoost": AdaBoostClassifier(random_state=42),
}

# %%
X_train_no_sa = df_global_train[ta_fa_feature_selected]
X_test_no_sa = df_global_test[ta_fa_feature_selected]
y_train = df_global_train[target]
y_test = df_global_test[target]
scaler = StandardScaler()
X_train_no_sa_scaled = scaler.fit_transform(X_train_no_sa)
X_test_no_sa_scaled = scaler.transform(X_test_no_sa)

# %%
X_train_with_sa = df_global_train[features]  # features = ta + fa + sa
X_test_with_sa = df_global_test[features]
y_train = df_global_train[target]
y_test = df_global_test[target]

scaler = StandardScaler()
X_train_with_sa_scaled = scaler.fit_transform(X_train_with_sa)   # Fit scaler trên train, scale train luôn
X_test_with_sa_scaled = scaler.transform(X_test_with_sa)

# %%
# ==============================================Tuning RF with Optuna + TimeSeriesSplit validate (AUC macro) ===============================================

# %% [markdown]
# Divide 5 fold to cross validation though tuning parameters

# %%
def get_grouped_time_series_folds(df, ticker_col='ticker', n_splits=5):
    tickers = df[ticker_col].unique()
    fold_indices = [[] for _ in range(n_splits)]  # List chứa n_splits fold tổng
    for ticker in tickers:
        idx = df[df[ticker_col] == ticker].index.values
        tscv = TimeSeriesSplit(n_splits=n_splits)
        for fold_num, (train_idx, val_idx) in enumerate(tscv.split(idx)):
            # Gộp index thực tế vào fold tổng tương ứng
            fold_indices[fold_num].append((idx[train_idx], idx[val_idx]))
    # Gộp index của từng fold tổng lại thành mảng train/val duy nhất
    grouped_folds = []
    for fold in fold_indices:
        train_idx = np.concatenate([item[0] for item in fold])
        val_idx = np.concatenate([item[1] for item in fold])
        grouped_folds.append((train_idx, val_idx))
    return grouped_folds

# %%
folds = get_grouped_time_series_folds(df_global_train, ticker_col='ticker', n_splits=5)

# %% [markdown]
# Tuning random forest for stock trend with ta + fa data

# %%
X_no_sa = X_train_no_sa_scaled  # hoặc X_train_with_sa_scaled nếu dùng cả SA
y = y_train

# %%
print("Tuning RandomForestClassifier with Optuna (AUC macro) ta + fa features only")

def objective_rf(trial):
    params = {
        "n_estimators": trial.suggest_int("n_estimators", 100, 600),
        "max_depth": trial.suggest_int("max_depth", 5, 25),
        "min_samples_split": trial.suggest_int("min_samples_split", 2, 10),
        "min_samples_leaf": trial.suggest_int("min_samples_leaf", 1, 8),
        "max_features": trial.suggest_categorical("max_features", ["sqrt", "log2", 0.2, 0.4, 0.6, 0.8]),
        "class_weight": "balanced_subsample",
        "random_state": 42,
        "n_jobs": -1,
    }

    aucs = []
    for train_idx, val_idx in folds:
        X_train, X_val = X_no_sa[train_idx], X_no_sa[val_idx]
        y_train_fold, y_val_fold = y.iloc[train_idx], y.iloc[val_idx]
        model = RandomForestClassifier(**params)
        model.fit(X_train, y_train_fold)
        # One-hot encode y_val_fold
        y_val_bin = label_binarize(y_val_fold, classes=[0,1,2])
        y_pred_proba = model.predict_proba(X_val)
        # Nếu predict_proba trả về list (multioutput), cần stack lại
        if isinstance(y_pred_proba, list):
            y_pred_proba = np.stack([p[:,1] for p in y_pred_proba], axis=1)
        auc_macro = roc_auc_score(y_val_bin, y_pred_proba, average="macro", multi_class="ovr")
        aucs.append(auc_macro)
    mean_auc = np.mean(aucs)
    print(f"Trial {trial.number}: AUC macro={mean_auc:.5f}, params={trial.params}")
    # Optuna sẽ maximize AUC macro
    return -mean_auc

study = optuna.create_study(direction="minimize")
study.optimize(objective_rf, n_trials=50)

print("Best AUC macro (RandomForest):", -study.best_value)
print("Best params (RandomForest):", study.best_trial.params)
# Out:
# [I 2025-06-20 05:40:20,546] A new study created in memory with name: no-name-f817c385-656e-4eb0-93b4-9fcf39b20e29
# Tuning RandomForestClassifier with Optuna (AUC macro) ta + fa features only
# [I 2025-06-20 06:06:57,726] Trial 0 finished with value: -0.6362102570558832 and parameters: {'n_estimators': 343, 'max_depth': 16, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8}. Best is trial 0 with value: -0.6362102570558832.
# Trial 0: AUC macro=0.63621, params={'n_estimators': 343, 'max_depth': 16, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8}
# [I 2025-06-20 06:09:16,106] Trial 1 finished with value: -0.6390767749047928 and parameters: {'n_estimators': 124, 'max_depth': 6, 'min_samples_split': 5, 'min_samples_leaf': 6, 'max_features': 0.4}. Best is trial 1 with value: -0.6390767749047928.
# Trial 1: AUC macro=0.63908, params={'n_estimators': 124, 'max_depth': 6, 'min_samples_split': 5, 'min_samples_leaf': 6, 'max_features': 0.4}
# [I 2025-06-20 06:19:31,120] Trial 2 finished with value: -0.6383884959665365 and parameters: {'n_estimators': 323, 'max_depth': 7, 'min_samples_split': 5, 'min_samples_leaf': 7, 'max_features': 0.6}. Best is trial 1 with value: -0.6390767749047928.
# Trial 2: AUC macro=0.63839, params={'n_estimators': 323, 'max_depth': 7, 'min_samples_split': 5, 'min_samples_leaf': 7, 'max_features': 0.6}
# [I 2025-06-20 06:22:27,289] Trial 3 finished with value: -0.6568231752619937 and parameters: {'n_estimators': 399, 'max_depth': 24, 'min_samples_split': 7, 'min_samples_leaf': 8, 'max_features': 'sqrt'}. Best is trial 3 with value: -0.6568231752619937.
# Trial 3: AUC macro=0.65682, params={'n_estimators': 399, 'max_depth': 24, 'min_samples_split': 7, 'min_samples_leaf': 8, 'max_features': 'sqrt'}
# [I 2025-06-20 06:30:26,483] Trial 4 finished with value: -0.6384483819244989 and parameters: {'n_estimators': 431, 'max_depth': 6, 'min_samples_split': 3, 'min_samples_leaf': 8, 'max_features': 0.4}. Best is trial 3 with value: -0.6568231752619937.
# Trial 4: AUC macro=0.63845, params={'n_estimators': 431, 'max_depth': 6, 'min_samples_split': 3, 'min_samples_leaf': 8, 'max_features': 0.4}
# [I 2025-06-20 06:42:03,534] Trial 5 finished with value: -0.6484705452630666 and parameters: {'n_estimators': 308, 'max_depth': 22, 'min_samples_split': 10, 'min_samples_leaf': 8, 'max_features': 0.4}. Best is trial 3 with value: -0.6568231752619937.
# Trial 5: AUC macro=0.64847, params={'n_estimators': 308, 'max_depth': 22, 'min_samples_split': 10, 'min_samples_leaf': 8, 'max_features': 0.4}
# [I 2025-06-20 07:02:48,297] Trial 6 finished with value: -0.6461260007369939 and parameters: {'n_estimators': 355, 'max_depth': 20, 'min_samples_split': 8, 'min_samples_leaf': 5, 'max_features': 0.6}. Best is trial 3 with value: -0.6568231752619937.
# Trial 6: AUC macro=0.64613, params={'n_estimators': 355, 'max_depth': 20, 'min_samples_split': 8, 'min_samples_leaf': 5, 'max_features': 0.6}
# [I 2025-06-20 07:10:20,441] Trial 7 finished with value: -0.6425298206160741 and parameters: {'n_estimators': 361, 'max_depth': 7, 'min_samples_split': 4, 'min_samples_leaf': 3, 'max_features': 0.4}. Best is trial 3 with value: -0.6568231752619937.
# Trial 7: AUC macro=0.64253, params={'n_estimators': 361, 'max_depth': 7, 'min_samples_split': 4, 'min_samples_leaf': 3, 'max_features': 0.4}
# [I 2025-06-20 07:10:57,872] Trial 8 finished with value: -0.6472021036074452 and parameters: {'n_estimators': 140, 'max_depth': 25, 'min_samples_split': 6, 'min_samples_leaf': 4, 'max_features': 'log2'}. Best is trial 3 with value: -0.6568231752619937.
# Trial 8: AUC macro=0.64720, params={'n_estimators': 140, 'max_depth': 25, 'min_samples_split': 6, 'min_samples_leaf': 4, 'max_features': 'log2'}
# [I 2025-06-20 07:12:50,313] Trial 9 finished with value: -0.6479773414317622 and parameters: {'n_estimators': 154, 'max_depth': 8, 'min_samples_split': 5, 'min_samples_leaf': 6, 'max_features': 0.2}. Best is trial 3 with value: -0.6568231752619937.
# Trial 9: AUC macro=0.64798, params={'n_estimators': 154, 'max_depth': 8, 'min_samples_split': 5, 'min_samples_leaf': 6, 'max_features': 0.2}
# [I 2025-06-20 07:16:32,843] Trial 10 finished with value: -0.6558390840331642 and parameters: {'n_estimators': 566, 'max_depth': 13, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': 'sqrt'}. Best is trial 3 with value: -0.6568231752619937.
# Trial 10: AUC macro=0.65584, params={'n_estimators': 566, 'max_depth': 13, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': 'sqrt'}
# [I 2025-06-20 07:20:35,773] Trial 11 finished with value: -0.6573007888805396 and parameters: {'n_estimators': 594, 'max_depth': 14, 'min_samples_split': 8, 'min_samples_leaf': 2, 'max_features': 'sqrt'}. Best is trial 11 with value: -0.6573007888805396.
# Trial 11: AUC macro=0.65730, params={'n_estimators': 594, 'max_depth': 14, 'min_samples_split': 8, 'min_samples_leaf': 2, 'max_features': 'sqrt'}
# [I 2025-06-20 07:24:33,031] Trial 12 finished with value: -0.656852419954572 and parameters: {'n_estimators': 599, 'max_depth': 13, 'min_samples_split': 8, 'min_samples_leaf': 1, 'max_features': 'sqrt'}. Best is trial 11 with value: -0.6573007888805396.
# Trial 12: AUC macro=0.65685, params={'n_estimators': 599, 'max_depth': 13, 'min_samples_split': 8, 'min_samples_leaf': 1, 'max_features': 'sqrt'}
# [I 2025-06-20 07:28:27,160] Trial 13 finished with value: -0.6553217450478684 and parameters: {'n_estimators': 596, 'max_depth': 13, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_features': 'sqrt'}. Best is trial 11 with value: -0.6573007888805396.
# Trial 13: AUC macro=0.65532, params={'n_estimators': 596, 'max_depth': 13, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_features': 'sqrt'}
# [I 2025-06-20 07:32:05,045] Trial 14 finished with value: -0.657299794964354 and parameters: {'n_estimators': 494, 'max_depth': 16, 'min_samples_split': 8, 'min_samples_leaf': 2, 'max_features': 'sqrt'}. Best is trial 11 with value: -0.6573007888805396.
# Trial 14: AUC macro=0.65730, params={'n_estimators': 494, 'max_depth': 16, 'min_samples_split': 8, 'min_samples_leaf': 2, 'max_features': 'sqrt'}
# [I 2025-06-20 07:35:49,285] Trial 15 finished with value: -0.657341720997101 and parameters: {'n_estimators': 497, 'max_depth': 17, 'min_samples_split': 9, 'min_samples_leaf': 2, 'max_features': 'sqrt'}. Best is trial 15 with value: -0.657341720997101.
# Trial 15: AUC macro=0.65734, params={'n_estimators': 497, 'max_depth': 17, 'min_samples_split': 9, 'min_samples_leaf': 2, 'max_features': 'sqrt'}
# [I 2025-06-20 07:46:08,805] Trial 16 finished with value: -0.6540517509658637 and parameters: {'n_estimators': 509, 'max_depth': 19, 'min_samples_split': 9, 'min_samples_leaf': 3, 'max_features': 0.2}. Best is trial 15 with value: -0.657341720997101.
# Trial 16: AUC macro=0.65405, params={'n_estimators': 509, 'max_depth': 19, 'min_samples_split': 9, 'min_samples_leaf': 3, 'max_features': 0.2}
# [I 2025-06-20 08:14:42,401] Trial 17 finished with value: -0.6379447444095425 and parameters: {'n_estimators': 511, 'max_depth': 10, 'min_samples_split': 9, 'min_samples_leaf': 2, 'max_features': 0.8}. Best is trial 15 with value: -0.657341720997101.
# Trial 17: AUC macro=0.63794, params={'n_estimators': 511, 'max_depth': 10, 'min_samples_split': 9, 'min_samples_leaf': 2, 'max_features': 0.8}
# [I 2025-06-20 08:16:35,285] Trial 18 finished with value: -0.6586803632284306 and parameters: {'n_estimators': 452, 'max_depth': 18, 'min_samples_split': 9, 'min_samples_leaf': 4, 'max_features': 'log2'}. Best is trial 18 with value: -0.6586803632284306.
# Trial 18: AUC macro=0.65868, params={'n_estimators': 452, 'max_depth': 18, 'min_samples_split': 9, 'min_samples_leaf': 4, 'max_features': 'log2'}
# [I 2025-06-20 08:17:32,478] Trial 19 finished with value: -0.6562447492323755 and parameters: {'n_estimators': 227, 'max_depth': 18, 'min_samples_split': 10, 'min_samples_leaf': 4, 'max_features': 'log2'}. Best is trial 18 with value: -0.6586803632284306.
# Trial 19: AUC macro=0.65624, params={'n_estimators': 227, 'max_depth': 18, 'min_samples_split': 10, 'min_samples_leaf': 4, 'max_features': 'log2'}
# [I 2025-06-20 08:19:29,098] Trial 20 finished with value: -0.6573211058660211 and parameters: {'n_estimators': 459, 'max_depth': 22, 'min_samples_split': 7, 'min_samples_leaf': 5, 'max_features': 'log2'}. Best is trial 18 with value: -0.6586803632284306.
# Trial 20: AUC macro=0.65732, params={'n_estimators': 459, 'max_depth': 22, 'min_samples_split': 7, 'min_samples_leaf': 5, 'max_features': 'log2'}
# [I 2025-06-20 08:21:21,721] Trial 21 finished with value: -0.6572303527788794 and parameters: {'n_estimators': 449, 'max_depth': 21, 'min_samples_split': 7, 'min_samples_leaf': 5, 'max_features': 'log2'}. Best is trial 18 with value: -0.6586803632284306.
# Trial 21: AUC macro=0.65723, params={'n_estimators': 449, 'max_depth': 21, 'min_samples_split': 7, 'min_samples_leaf': 5, 'max_features': 'log2'}
# [I 2025-06-20 08:23:16,858] Trial 22 finished with value: -0.6567559870237467 and parameters: {'n_estimators': 459, 'max_depth': 23, 'min_samples_split': 9, 'min_samples_leaf': 6, 'max_features': 'log2'}. Best is trial 18 with value: -0.6586803632284306.
# Trial 22: AUC macro=0.65676, params={'n_estimators': 459, 'max_depth': 23, 'min_samples_split': 9, 'min_samples_leaf': 6, 'max_features': 'log2'}
# [I 2025-06-20 08:25:33,432] Trial 23 finished with value: -0.6581487287309353 and parameters: {'n_estimators': 543, 'max_depth': 18, 'min_samples_split': 7, 'min_samples_leaf': 4, 'max_features': 'log2'}. Best is trial 18 with value: -0.6586803632284306.
# Trial 23: AUC macro=0.65815, params={'n_estimators': 543, 'max_depth': 18, 'min_samples_split': 7, 'min_samples_leaf': 4, 'max_features': 'log2'}
# [I 2025-06-20 08:27:52,008] Trial 24 finished with value: -0.6581287908041783 and parameters: {'n_estimators': 545, 'max_depth': 18, 'min_samples_split': 6, 'min_samples_leaf': 4, 'max_features': 'log2'}. Best is trial 18 with value: -0.6586803632284306.
# Trial 24: AUC macro=0.65813, params={'n_estimators': 545, 'max_depth': 18, 'min_samples_split': 6, 'min_samples_leaf': 4, 'max_features': 'log2'}
# [I 2025-06-20 08:30:10,610] Trial 25 finished with value: -0.657817440102861 and parameters: {'n_estimators': 544, 'max_depth': 19, 'min_samples_split': 6, 'min_samples_leaf': 4, 'max_features': 'log2'}. Best is trial 18 with value: -0.6586803632284306.
# Trial 25: AUC macro=0.65782, params={'n_estimators': 544, 'max_depth': 19, 'min_samples_split': 6, 'min_samples_leaf': 4, 'max_features': 'log2'}
# [I 2025-06-20 08:32:17,044] Trial 26 finished with value: -0.6586590918477424 and parameters: {'n_estimators': 543, 'max_depth': 15, 'min_samples_split': 6, 'min_samples_leaf': 4, 'max_features': 'log2'}. Best is trial 18 with value: -0.6586803632284306.
# Trial 26: AUC macro=0.65866, params={'n_estimators': 543, 'max_depth': 15, 'min_samples_split': 6, 'min_samples_leaf': 4, 'max_features': 'log2'}
# [I 2025-06-20 08:33:55,859] Trial 27 finished with value: -0.6561695767858233 and parameters: {'n_estimators': 406, 'max_depth': 16, 'min_samples_split': 4, 'min_samples_leaf': 3, 'max_features': 'log2'}. Best is trial 18 with value: -0.6586803632284306.
# Trial 27: AUC macro=0.65617, params={'n_estimators': 406, 'max_depth': 16, 'min_samples_split': 4, 'min_samples_leaf': 3, 'max_features': 'log2'}
# [I 2025-06-20 08:35:42,485] Trial 28 finished with value: -0.6540591966101197 and parameters: {'n_estimators': 547, 'max_depth': 11, 'min_samples_split': 7, 'min_samples_leaf': 5, 'max_features': 'log2'}. Best is trial 18 with value: -0.6586803632284306.
# Trial 28: AUC macro=0.65406, params={'n_estimators': 547, 'max_depth': 11, 'min_samples_split': 7, 'min_samples_leaf': 5, 'max_features': 'log2'}
# [I 2025-06-20 08:55:33,831] Trial 29 finished with value: -0.6438465368920964 and parameters: {'n_estimators': 276, 'max_depth': 15, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_features': 0.8}. Best is trial 18 with value: -0.6586803632284306.
# Trial 29: AUC macro=0.64385, params={'n_estimators': 276, 'max_depth': 15, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_features': 0.8}
# [I 2025-06-20 08:57:29,589] Trial 30 finished with value: -0.656416058924483 and parameters: {'n_estimators': 478, 'max_depth': 15, 'min_samples_split': 6, 'min_samples_leaf': 3, 'max_features': 'log2'}. Best is trial 18 with value: -0.6586803632284306.
# Trial 30: AUC macro=0.65642, params={'n_estimators': 478, 'max_depth': 15, 'min_samples_split': 6, 'min_samples_leaf': 3, 'max_features': 'log2'}
# [I 2025-06-20 08:59:45,153] Trial 31 finished with value: -0.6580032563648065 and parameters: {'n_estimators': 532, 'max_depth': 18, 'min_samples_split': 6, 'min_samples_leaf': 4, 'max_features': 'log2'}. Best is trial 18 with value: -0.6586803632284306.
# Trial 31: AUC macro=0.65800, params={'n_estimators': 532, 'max_depth': 18, 'min_samples_split': 6, 'min_samples_leaf': 4, 'max_features': 'log2'}
# [I 2025-06-20 09:02:06,997] Trial 32 finished with value: -0.6580200200785462 and parameters: {'n_estimators': 569, 'max_depth': 17, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': 'log2'}. Best is trial 18 with value: -0.6586803632284306.
# Trial 32: AUC macro=0.65802, params={'n_estimators': 569, 'max_depth': 17, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': 'log2'}
# [I 2025-06-20 09:03:53,364] Trial 33 finished with value: -0.656855136679504 and parameters: {'n_estimators': 413, 'max_depth': 20, 'min_samples_split': 4, 'min_samples_leaf': 5, 'max_features': 'log2'}. Best is trial 18 with value: -0.6586803632284306.
# Trial 33: AUC macro=0.65686, params={'n_estimators': 413, 'max_depth': 20, 'min_samples_split': 4, 'min_samples_leaf': 5, 'max_features': 'log2'}
# [I 2025-06-20 09:33:04,475] Trial 34 finished with value: -0.6467023927350308 and parameters: {'n_estimators': 527, 'max_depth': 17, 'min_samples_split': 6, 'min_samples_leaf': 6, 'max_features': 0.6}. Best is trial 18 with value: -0.6586803632284306.
# Trial 34: AUC macro=0.64670, params={'n_estimators': 527, 'max_depth': 17, 'min_samples_split': 6, 'min_samples_leaf': 6, 'max_features': 0.6}
# [I 2025-06-20 09:35:21,384] Trial 35 finished with value: -0.6567702618395631 and parameters: {'n_estimators': 564, 'max_depth': 19, 'min_samples_split': 7, 'min_samples_leaf': 7, 'max_features': 'log2'}. Best is trial 18 with value: -0.6586803632284306.
# Trial 35: AUC macro=0.65677, params={'n_estimators': 564, 'max_depth': 19, 'min_samples_split': 7, 'min_samples_leaf': 7, 'max_features': 'log2'}
# [I 2025-06-20 09:44:33,542] Trial 36 finished with value: -0.6548786257846504 and parameters: {'n_estimators': 473, 'max_depth': 16, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': 0.2}. Best is trial 18 with value: -0.6586803632284306.
# Trial 36: AUC macro=0.65488, params={'n_estimators': 473, 'max_depth': 16, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': 0.2}
# [I 2025-06-20 10:07:07,580] Trial 37 finished with value: -0.6400298960151409 and parameters: {'n_estimators': 378, 'max_depth': 11, 'min_samples_split': 7, 'min_samples_leaf': 3, 'max_features': 0.8}. Best is trial 18 with value: -0.6586803632284306.
# Trial 37: AUC macro=0.64003, params={'n_estimators': 378, 'max_depth': 11, 'min_samples_split': 7, 'min_samples_leaf': 3, 'max_features': 0.8}
# [I 2025-06-20 10:29:45,589] Trial 38 finished with value: -0.6451345853912841 and parameters: {'n_estimators': 434, 'max_depth': 14, 'min_samples_split': 6, 'min_samples_leaf': 5, 'max_features': 0.6}. Best is trial 18 with value: -0.6586803632284306.
# Trial 38: AUC macro=0.64513, params={'n_estimators': 434, 'max_depth': 14, 'min_samples_split': 6, 'min_samples_leaf': 5, 'max_features': 0.6}
# [I 2025-06-20 10:49:15,797] Trial 39 finished with value: -0.6510758921241536 and parameters: {'n_estimators': 519, 'max_depth': 21, 'min_samples_split': 4, 'min_samples_leaf': 7, 'max_features': 0.4}. Best is trial 18 with value: -0.6586803632284306.
# Trial 39: AUC macro=0.65108, params={'n_estimators': 519, 'max_depth': 21, 'min_samples_split': 4, 'min_samples_leaf': 7, 'max_features': 0.4}
# [I 2025-06-20 10:51:38,683] Trial 40 finished with value: -0.6584187946128147 and parameters: {'n_estimators': 568, 'max_depth': 18, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': 'log2'}. Best is trial 18 with value: -0.6586803632284306.
# Trial 40: AUC macro=0.65842, params={'n_estimators': 568, 'max_depth': 18, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': 'log2'}
# [I 2025-06-20 10:53:59,350] Trial 41 finished with value: -0.6582832940350855 and parameters: {'n_estimators': 562, 'max_depth': 18, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': 'log2'}. Best is trial 18 with value: -0.6586803632284306.
# Trial 41: AUC macro=0.65828, params={'n_estimators': 562, 'max_depth': 18, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': 'log2'}
# [I 2025-06-20 10:56:31,777] Trial 42 finished with value: -0.6583470849486692 and parameters: {'n_estimators': 578, 'max_depth': 20, 'min_samples_split': 5, 'min_samples_leaf': 3, 'max_features': 'log2'}. Best is trial 18 with value: -0.6586803632284306.
# Trial 42: AUC macro=0.65835, params={'n_estimators': 578, 'max_depth': 20, 'min_samples_split': 5, 'min_samples_leaf': 3, 'max_features': 'log2'}
# [I 2025-06-20 10:59:04,162] Trial 43 finished with value: -0.6583142590103359 and parameters: {'n_estimators': 574, 'max_depth': 20, 'min_samples_split': 5, 'min_samples_leaf': 3, 'max_features': 'log2'}. Best is trial 18 with value: -0.6586803632284306.
# Trial 43: AUC macro=0.65831, params={'n_estimators': 574, 'max_depth': 20, 'min_samples_split': 5, 'min_samples_leaf': 3, 'max_features': 'log2'}
# [I 2025-06-20 11:01:37,645] Trial 44 finished with value: -0.6583451883000476 and parameters: {'n_estimators': 582, 'max_depth': 20, 'min_samples_split': 5, 'min_samples_leaf': 3, 'max_features': 'log2'}. Best is trial 18 with value: -0.6586803632284306.
# Trial 44: AUC macro=0.65835, params={'n_estimators': 582, 'max_depth': 20, 'min_samples_split': 5, 'min_samples_leaf': 3, 'max_features': 'log2'}
# [I 2025-06-20 11:26:37,946] Trial 45 finished with value: -0.6487308233413965 and parameters: {'n_estimators': 581, 'max_depth': 24, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 0.4}. Best is trial 18 with value: -0.6586803632284306.
# Trial 45: AUC macro=0.64873, params={'n_estimators': 581, 'max_depth': 24, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 0.4}
# [I 2025-06-20 11:28:49,411] Trial 46 finished with value: -0.6559047201295771 and parameters: {'n_estimators': 490, 'max_depth': 21, 'min_samples_split': 4, 'min_samples_leaf': 3, 'max_features': 'log2'}. Best is trial 18 with value: -0.6586803632284306.
# Trial 46: AUC macro=0.65590, params={'n_estimators': 490, 'max_depth': 21, 'min_samples_split': 4, 'min_samples_leaf': 3, 'max_features': 'log2'}
# [I 2025-06-20 11:31:29,405] Trial 47 finished with value: -0.6580378369076701 and parameters: {'n_estimators': 596, 'max_depth': 22, 'min_samples_split': 3, 'min_samples_leaf': 3, 'max_features': 'log2'}. Best is trial 18 with value: -0.6586803632284306.
# Trial 47: AUC macro=0.65804, params={'n_estimators': 596, 'max_depth': 22, 'min_samples_split': 3, 'min_samples_leaf': 3, 'max_features': 'log2'}
# [I 2025-06-20 11:43:42,030] Trial 48 finished with value: -0.6546961522719775 and parameters: {'n_estimators': 581, 'max_depth': 20, 'min_samples_split': 3, 'min_samples_leaf': 3, 'max_features': 0.2}. Best is trial 18 with value: -0.6586803632284306.
# Trial 48: AUC macro=0.65470, params={'n_estimators': 581, 'max_depth': 20, 'min_samples_split': 3, 'min_samples_leaf': 3, 'max_features': 0.2}
# [I 2025-06-20 12:02:49,562] Trial 49 finished with value: -0.6459179727683682 and parameters: {'n_estimators': 319, 'max_depth': 25, 'min_samples_split': 4, 'min_samples_leaf': 5, 'max_features': 0.6}. Best is trial 18 with value: -0.6586803632284306.
# Trial 49: AUC macro=0.64592, params={'n_estimators': 319, 'max_depth': 25, 'min_samples_split': 4, 'min_samples_leaf': 5, 'max_features': 0.6}
# Best AUC macro (RandomForest): 0.6586803632284306
# Best params (RandomForest): {'n_estimators': 452, 'max_depth': 18, 'min_samples_split': 9, 'min_samples_leaf': 4, 'max_features': 'log2'}

# %% [markdown]
# Tuning random forest for stock trend with ta + fa + sa data

# %%
X_with_sa = X_train_with_sa_scaled  
y = y_train

# %%
print("Tuning RandomForestClassifier with Optuna (AUC macro) ta + fa + sa features")

def objective_rf(trial):
    params = {
        "n_estimators": trial.suggest_int("n_estimators", 200, 800),  # tăng upper bound vì nhiều feature hơn
        "max_depth": trial.suggest_int("max_depth", 8, 28),           # tăng nhẹ max_depth
        "min_samples_split": trial.suggest_int("min_samples_split", 2, 12),
        "min_samples_leaf": trial.suggest_int("min_samples_leaf", 1, 10),
        "max_features": trial.suggest_categorical(
            "max_features", ["sqrt", "log2", 0.1, 0.2, 0.3, 0.4]
        ),  # thêm các tỷ lệ nhỏ hơn vì số feature lớn
        "class_weight": "balanced_subsample",
        "random_state": 42,
        "n_jobs": -1,
    }

    aucs = []
    for train_idx, val_idx in folds:
        X_train, X_val = X_with_sa[train_idx], X_with_sa[val_idx]
        y_train_fold, y_val_fold = y.iloc[train_idx], y.iloc[val_idx]
        model = RandomForestClassifier(**params)
        model.fit(X_train, y_train_fold)
        # One-hot encode y_val_fold
        y_val_bin = label_binarize(y_val_fold, classes=[0,1,2])
        y_pred_proba = model.predict_proba(X_val)
        # Nếu predict_proba trả về list (multioutput), cần stack lại
        if isinstance(y_pred_proba, list):
            y_pred_proba = np.stack([p[:,1] for p in y_pred_proba], axis=1)
        auc_macro = roc_auc_score(y_val_bin, y_pred_proba, average="macro", multi_class="ovr")
        aucs.append(auc_macro)
    mean_auc = np.mean(aucs)
    print(f"Trial {trial.number}: AUC macro={mean_auc:.5f}, params={trial.params}")
    # Optuna sẽ maximize AUC macro
    return -mean_auc

study = optuna.create_study(direction="minimize")
study.optimize(objective_rf, n_trials=50)

print("Best AUC macro (RandomForest):", -study.best_value)
print("Best params (RandomForest):", study.best_trial.params)
# Out:
# [I 2025-06-20 23:02:31,973] A new study created in memory with name: no-name-e5aebc65-04f9-4d0f-afbc-1c998626293e
# Tuning RandomForestClassifier with Optuna (AUC macro) ta + fa + sa features
# [I 2025-06-20 23:11:28,736] Trial 0 finished with value: -0.659167545596102 and parameters: {'n_estimators': 358, 'max_depth': 12, 'min_samples_split': 3, 'min_samples_leaf': 3, 'max_features': 0.3}. Best is trial 0 with value: -0.659167545596102.
# Trial 0: AUC macro=0.65917, params={'n_estimators': 358, 'max_depth': 12, 'min_samples_split': 3, 'min_samples_leaf': 3, 'max_features': 0.3}
# [I 2025-06-20 23:26:50,194] Trial 1 finished with value: -0.6577516585250482 and parameters: {'n_estimators': 344, 'max_depth': 23, 'min_samples_split': 11, 'min_samples_leaf': 1, 'max_features': 0.4}. Best is trial 0 with value: -0.659167545596102.
# Trial 1: AUC macro=0.65775, params={'n_estimators': 344, 'max_depth': 23, 'min_samples_split': 11, 'min_samples_leaf': 1, 'max_features': 0.4}
# [I 2025-06-20 23:27:38,814] Trial 2 finished with value: -0.6594623813986079 and parameters: {'n_estimators': 215, 'max_depth': 8, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_features': 'sqrt'}. Best is trial 2 with value: -0.6594623813986079.
# Trial 2: AUC macro=0.65946, params={'n_estimators': 215, 'max_depth': 8, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_features': 'sqrt'}
# [I 2025-06-20 23:37:53,644] Trial 3 finished with value: -0.6595294706270046 and parameters: {'n_estimators': 702, 'max_depth': 10, 'min_samples_split': 4, 'min_samples_leaf': 2, 'max_features': 0.2}. Best is trial 3 with value: -0.6595294706270046.
# Trial 3: AUC macro=0.65953, params={'n_estimators': 702, 'max_depth': 10, 'min_samples_split': 4, 'min_samples_leaf': 2, 'max_features': 0.2}
# [I 2025-06-20 23:41:44,622] Trial 4 finished with value: -0.666616617638075 and parameters: {'n_estimators': 364, 'max_depth': 21, 'min_samples_split': 11, 'min_samples_leaf': 5, 'max_features': 0.1}. Best is trial 4 with value: -0.666616617638075.
# Trial 4: AUC macro=0.66662, params={'n_estimators': 364, 'max_depth': 21, 'min_samples_split': 11, 'min_samples_leaf': 5, 'max_features': 0.1}
# [I 2025-06-20 23:57:02,673] Trial 5 finished with value: -0.6671699175705834 and parameters: {'n_estimators': 777, 'max_depth': 23, 'min_samples_split': 5, 'min_samples_leaf': 7, 'max_features': 0.2}. Best is trial 5 with value: -0.6671699175705834.
# Trial 5: AUC macro=0.66717, params={'n_estimators': 777, 'max_depth': 23, 'min_samples_split': 5, 'min_samples_leaf': 7, 'max_features': 0.2}
# [I 2025-06-21 00:01:06,559] Trial 6 finished with value: -0.6615702245359858 and parameters: {'n_estimators': 590, 'max_depth': 9, 'min_samples_split': 3, 'min_samples_leaf': 3, 'max_features': 0.1}. Best is trial 5 with value: -0.6671699175705834.
# Trial 6: AUC macro=0.66157, params={'n_estimators': 590, 'max_depth': 9, 'min_samples_split': 3, 'min_samples_leaf': 3, 'max_features': 0.1}
# [I 2025-06-21 00:37:54,588] Trial 7 finished with value: -0.6578452029407852 and parameters: {'n_estimators': 796, 'max_depth': 25, 'min_samples_split': 4, 'min_samples_leaf': 1, 'max_features': 0.4}. Best is trial 5 with value: -0.6671699175705834.
# Trial 7: AUC macro=0.65785, params={'n_estimators': 796, 'max_depth': 25, 'min_samples_split': 4, 'min_samples_leaf': 1, 'max_features': 0.4}
# [I 2025-06-21 00:40:20,134] Trial 8 finished with value: -0.6656267569907446 and parameters: {'n_estimators': 226, 'max_depth': 26, 'min_samples_split': 10, 'min_samples_leaf': 6, 'max_features': 0.1}. Best is trial 5 with value: -0.6671699175705834.
# Trial 8: AUC macro=0.66563, params={'n_estimators': 226, 'max_depth': 26, 'min_samples_split': 10, 'min_samples_leaf': 6, 'max_features': 0.1}
# [I 2025-06-21 00:41:39,566] Trial 9 finished with value: -0.6624429097766218 and parameters: {'n_estimators': 493, 'max_depth': 11, 'min_samples_split': 9, 'min_samples_leaf': 6, 'max_features': 'log2'}. Best is trial 5 with value: -0.6671699175705834.
# Trial 9: AUC macro=0.66244, params={'n_estimators': 493, 'max_depth': 11, 'min_samples_split': 9, 'min_samples_leaf': 6, 'max_features': 'log2'}
# [I 2025-06-21 00:53:01,747] Trial 10 finished with value: -0.6644027090925804 and parameters: {'n_estimators': 630, 'max_depth': 16, 'min_samples_split': 7, 'min_samples_leaf': 10, 'max_features': 0.2}. Best is trial 5 with value: -0.6671699175705834.
# Trial 10: AUC macro=0.66440, params={'n_estimators': 630, 'max_depth': 16, 'min_samples_split': 7, 'min_samples_leaf': 10, 'max_features': 0.2}
# [I 2025-06-21 00:57:31,006] Trial 11 finished with value: -0.6679301366505187 and parameters: {'n_estimators': 452, 'max_depth': 20, 'min_samples_split': 7, 'min_samples_leaf': 8, 'max_features': 0.1}. Best is trial 11 with value: -0.6679301366505187.
# Trial 11: AUC macro=0.66793, params={'n_estimators': 452, 'max_depth': 20, 'min_samples_split': 7, 'min_samples_leaf': 8, 'max_features': 0.1}
# [I 2025-06-21 01:06:42,906] Trial 12 finished with value: -0.6643641738561487 and parameters: {'n_estimators': 489, 'max_depth': 18, 'min_samples_split': 6, 'min_samples_leaf': 9, 'max_features': 0.2}. Best is trial 11 with value: -0.6679301366505187.
# Trial 12: AUC macro=0.66436, params={'n_estimators': 489, 'max_depth': 18, 'min_samples_split': 6, 'min_samples_leaf': 9, 'max_features': 0.2}
# [I 2025-06-21 01:11:37,658] Trial 13 finished with value: -0.669233725150313 and parameters: {'n_estimators': 794, 'max_depth': 28, 'min_samples_split': 6, 'min_samples_leaf': 8, 'max_features': 'sqrt'}. Best is trial 13 with value: -0.669233725150313.
# Trial 13: AUC macro=0.66923, params={'n_estimators': 794, 'max_depth': 28, 'min_samples_split': 6, 'min_samples_leaf': 8, 'max_features': 'sqrt'}
# [I 2025-06-21 01:15:12,343] Trial 14 finished with value: -0.6690562186482361 and parameters: {'n_estimators': 581, 'max_depth': 27, 'min_samples_split': 8, 'min_samples_leaf': 8, 'max_features': 'sqrt'}. Best is trial 13 with value: -0.669233725150313.
# Trial 14: AUC macro=0.66906, params={'n_estimators': 581, 'max_depth': 27, 'min_samples_split': 8, 'min_samples_leaf': 8, 'max_features': 'sqrt'}
# [I 2025-06-21 01:18:56,185] Trial 15 finished with value: -0.6688097953429935 and parameters: {'n_estimators': 605, 'max_depth': 28, 'min_samples_split': 8, 'min_samples_leaf': 8, 'max_features': 'sqrt'}. Best is trial 13 with value: -0.669233725150313.
# Trial 15: AUC macro=0.66881, params={'n_estimators': 605, 'max_depth': 28, 'min_samples_split': 8, 'min_samples_leaf': 8, 'max_features': 'sqrt'}
# [I 2025-06-21 01:23:10,663] Trial 16 finished with value: -0.6674006965940837 and parameters: {'n_estimators': 708, 'max_depth': 28, 'min_samples_split': 6, 'min_samples_leaf': 10, 'max_features': 'sqrt'}. Best is trial 13 with value: -0.669233725150313.
# Trial 16: AUC macro=0.66740, params={'n_estimators': 708, 'max_depth': 28, 'min_samples_split': 6, 'min_samples_leaf': 10, 'max_features': 'sqrt'}
# [I 2025-06-21 01:27:23,589] Trial 17 finished with value: -0.6689781681136391 and parameters: {'n_estimators': 686, 'max_depth': 25, 'min_samples_split': 8, 'min_samples_leaf': 8, 'max_features': 'sqrt'}. Best is trial 13 with value: -0.669233725150313.
# Trial 17: AUC macro=0.66898, params={'n_estimators': 686, 'max_depth': 25, 'min_samples_split': 8, 'min_samples_leaf': 8, 'max_features': 'sqrt'}
# [I 2025-06-21 01:30:33,501] Trial 18 finished with value: -0.6672755005401847 and parameters: {'n_estimators': 555, 'max_depth': 14, 'min_samples_split': 12, 'min_samples_leaf': 5, 'max_features': 'sqrt'}. Best is trial 13 with value: -0.669233725150313.
# Trial 18: AUC macro=0.66728, params={'n_estimators': 555, 'max_depth': 14, 'min_samples_split': 12, 'min_samples_leaf': 5, 'max_features': 'sqrt'}
# [I 2025-06-21 01:52:21,231] Trial 19 finished with value: -0.6634460125964281 and parameters: {'n_estimators': 746, 'max_depth': 28, 'min_samples_split': 2, 'min_samples_leaf': 7, 'max_features': 0.3}. Best is trial 13 with value: -0.669233725150313.
# Trial 19: AUC macro=0.66345, params={'n_estimators': 746, 'max_depth': 28, 'min_samples_split': 2, 'min_samples_leaf': 7, 'max_features': 0.3}
# [I 2025-06-21 01:53:46,232] Trial 20 finished with value: -0.6667078305454448 and parameters: {'n_estimators': 427, 'max_depth': 23, 'min_samples_split': 6, 'min_samples_leaf': 9, 'max_features': 'log2'}. Best is trial 13 with value: -0.669233725150313.
# Trial 20: AUC macro=0.66671, params={'n_estimators': 427, 'max_depth': 23, 'min_samples_split': 6, 'min_samples_leaf': 9, 'max_features': 'log2'}
# [I 2025-06-21 01:57:47,357] Trial 21 finished with value: -0.668877399099442 and parameters: {'n_estimators': 661, 'max_depth': 25, 'min_samples_split': 8, 'min_samples_leaf': 8, 'max_features': 'sqrt'}. Best is trial 13 with value: -0.669233725150313.
# Trial 21: AUC macro=0.66888, params={'n_estimators': 661, 'max_depth': 25, 'min_samples_split': 8, 'min_samples_leaf': 8, 'max_features': 'sqrt'}
# [I 2025-06-21 02:02:02,066] Trial 22 finished with value: -0.6681197604536874 and parameters: {'n_estimators': 685, 'max_depth': 26, 'min_samples_split': 8, 'min_samples_leaf': 7, 'max_features': 'sqrt'}. Best is trial 13 with value: -0.669233725150313.
# Trial 22: AUC macro=0.66812, params={'n_estimators': 685, 'max_depth': 26, 'min_samples_split': 8, 'min_samples_leaf': 7, 'max_features': 'sqrt'}
# [I 2025-06-21 02:05:24,651] Trial 23 finished with value: -0.6677465666273684 and parameters: {'n_estimators': 564, 'max_depth': 26, 'min_samples_split': 9, 'min_samples_leaf': 9, 'max_features': 'sqrt'}. Best is trial 13 with value: -0.669233725150313.
# Trial 23: AUC macro=0.66775, params={'n_estimators': 564, 'max_depth': 26, 'min_samples_split': 9, 'min_samples_leaf': 9, 'max_features': 'sqrt'}
# [I 2025-06-21 02:09:50,084] Trial 24 finished with value: -0.6687566369995459 and parameters: {'n_estimators': 735, 'max_depth': 21, 'min_samples_split': 9, 'min_samples_leaf': 8, 'max_features': 'sqrt'}. Best is trial 13 with value: -0.669233725150313.
# Trial 24: AUC macro=0.66876, params={'n_estimators': 735, 'max_depth': 21, 'min_samples_split': 9, 'min_samples_leaf': 8, 'max_features': 'sqrt'}
# [I 2025-06-21 02:14:01,700] Trial 25 finished with value: -0.6685735177589072 and parameters: {'n_estimators': 663, 'max_depth': 24, 'min_samples_split': 5, 'min_samples_leaf': 6, 'max_features': 'sqrt'}. Best is trial 13 with value: -0.669233725150313.
# Trial 25: AUC macro=0.66857, params={'n_estimators': 663, 'max_depth': 24, 'min_samples_split': 5, 'min_samples_leaf': 6, 'max_features': 'sqrt'}
# [I 2025-06-21 02:18:31,688] Trial 26 finished with value: -0.6678550601794482 and parameters: {'n_estimators': 748, 'max_depth': 27, 'min_samples_split': 7, 'min_samples_leaf': 9, 'max_features': 'sqrt'}. Best is trial 13 with value: -0.669233725150313.
# Trial 26: AUC macro=0.66786, params={'n_estimators': 748, 'max_depth': 27, 'min_samples_split': 7, 'min_samples_leaf': 9, 'max_features': 'sqrt'}
# [I 2025-06-21 02:21:48,826] Trial 27 finished with value: -0.667695163444469 and parameters: {'n_estimators': 544, 'max_depth': 19, 'min_samples_split': 8, 'min_samples_leaf': 7, 'max_features': 'sqrt'}. Best is trial 13 with value: -0.669233725150313.
# Trial 27: AUC macro=0.66770, params={'n_estimators': 544, 'max_depth': 19, 'min_samples_split': 8, 'min_samples_leaf': 7, 'max_features': 'sqrt'}
# [I 2025-06-21 02:45:21,284] Trial 28 finished with value: -0.6628881194538461 and parameters: {'n_estimators': 642, 'max_depth': 22, 'min_samples_split': 5, 'min_samples_leaf': 10, 'max_features': 0.4}. Best is trial 13 with value: -0.669233725150313.
# Trial 28: AUC macro=0.66289, params={'n_estimators': 642, 'max_depth': 22, 'min_samples_split': 5, 'min_samples_leaf': 10, 'max_features': 0.4}
# [I 2025-06-21 03:10:25,937] Trial 29 finished with value: -0.6640998896873126 and parameters: {'n_estimators': 799, 'max_depth': 25, 'min_samples_split': 7, 'min_samples_leaf': 4, 'max_features': 0.3}. Best is trial 13 with value: -0.669233725150313.
# Trial 29: AUC macro=0.66410, params={'n_estimators': 799, 'max_depth': 25, 'min_samples_split': 7, 'min_samples_leaf': 4, 'max_features': 0.3}
# [I 2025-06-21 03:12:23,429] Trial 30 finished with value: -0.6651863367509898 and parameters: {'n_estimators': 609, 'max_depth': 17, 'min_samples_split': 10, 'min_samples_leaf': 8, 'max_features': 'log2'}. Best is trial 13 with value: -0.669233725150313.
# Trial 30: AUC macro=0.66519, params={'n_estimators': 609, 'max_depth': 17, 'min_samples_split': 10, 'min_samples_leaf': 8, 'max_features': 'log2'}
# [I 2025-06-21 03:16:24,319] Trial 31 finished with value: -0.6688867387646557 and parameters: {'n_estimators': 660, 'max_depth': 25, 'min_samples_split': 8, 'min_samples_leaf': 8, 'max_features': 'sqrt'}. Best is trial 13 with value: -0.669233725150313.
# Trial 31: AUC macro=0.66889, params={'n_estimators': 660, 'max_depth': 25, 'min_samples_split': 8, 'min_samples_leaf': 8, 'max_features': 'sqrt'}
# [I 2025-06-21 03:20:49,309] Trial 32 finished with value: -0.6692364534732137 and parameters: {'n_estimators': 715, 'max_depth': 24, 'min_samples_split': 9, 'min_samples_leaf': 7, 'max_features': 'sqrt'}. Best is trial 32 with value: -0.6692364534732137.
# Trial 32: AUC macro=0.66924, params={'n_estimators': 715, 'max_depth': 24, 'min_samples_split': 9, 'min_samples_leaf': 7, 'max_features': 'sqrt'}
# [I 2025-06-21 03:25:16,242] Trial 33 finished with value: -0.6691905419154291 and parameters: {'n_estimators': 717, 'max_depth': 27, 'min_samples_split': 9, 'min_samples_leaf': 7, 'max_features': 'sqrt'}. Best is trial 32 with value: -0.6692364534732137.
# Trial 33: AUC macro=0.66919, params={'n_estimators': 717, 'max_depth': 27, 'min_samples_split': 9, 'min_samples_leaf': 7, 'max_features': 'sqrt'}
# [I 2025-06-21 03:29:55,485] Trial 34 finished with value: -0.6691805166489788 and parameters: {'n_estimators': 748, 'max_depth': 27, 'min_samples_split': 10, 'min_samples_leaf': 7, 'max_features': 'sqrt'}. Best is trial 32 with value: -0.6692364534732137.
# Trial 34: AUC macro=0.66918, params={'n_estimators': 748, 'max_depth': 27, 'min_samples_split': 10, 'min_samples_leaf': 7, 'max_features': 'sqrt'}
# [I 2025-06-21 03:51:36,877] Trial 35 finished with value: -0.6635052270936261 and parameters: {'n_estimators': 724, 'max_depth': 27, 'min_samples_split': 11, 'min_samples_leaf': 6, 'max_features': 0.3}. Best is trial 32 with value: -0.6692364534732137.
# Trial 35: AUC macro=0.66351, params={'n_estimators': 724, 'max_depth': 27, 'min_samples_split': 11, 'min_samples_leaf': 6, 'max_features': 0.3}
# [I 2025-06-21 03:56:20,159] Trial 36 finished with value: -0.6686247967848342 and parameters: {'n_estimators': 765, 'max_depth': 23, 'min_samples_split': 10, 'min_samples_leaf': 7, 'max_features': 'sqrt'}. Best is trial 32 with value: -0.6692364534732137.
# Trial 36: AUC macro=0.66862, params={'n_estimators': 765, 'max_depth': 23, 'min_samples_split': 10, 'min_samples_leaf': 7, 'max_features': 'sqrt'}
# [I 2025-06-21 04:27:21,915] Trial 37 finished with value: -0.6608186183584767 and parameters: {'n_estimators': 770, 'max_depth': 28, 'min_samples_split': 12, 'min_samples_leaf': 5, 'max_features': 0.4}. Best is trial 32 with value: -0.6692364534732137.
# Trial 37: AUC macro=0.66082, params={'n_estimators': 770, 'max_depth': 28, 'min_samples_split': 12, 'min_samples_leaf': 5, 'max_features': 0.4}
# [I 2025-06-21 04:31:59,694] Trial 38 finished with value: -0.6683180295089993 and parameters: {'n_estimators': 710, 'max_depth': 24, 'min_samples_split': 9, 'min_samples_leaf': 4, 'max_features': 'sqrt'}. Best is trial 32 with value: -0.6692364534732137.
# Trial 38: AUC macro=0.66832, params={'n_estimators': 710, 'max_depth': 24, 'min_samples_split': 9, 'min_samples_leaf': 4, 'max_features': 'sqrt'}
# [I 2025-06-21 04:36:55,404] Trial 39 finished with value: -0.6692048572444346 and parameters: {'n_estimators': 799, 'max_depth': 27, 'min_samples_split': 11, 'min_samples_leaf': 7, 'max_features': 'sqrt'}. Best is trial 32 with value: -0.6692364534732137.
# Trial 39: AUC macro=0.66920, params={'n_estimators': 799, 'max_depth': 27, 'min_samples_split': 11, 'min_samples_leaf': 7, 'max_features': 'sqrt'}
# [I 2025-06-21 05:08:12,711] Trial 40 finished with value: -0.6625814830750982 and parameters: {'n_estimators': 799, 'max_depth': 22, 'min_samples_split': 11, 'min_samples_leaf': 6, 'max_features': 0.4}. Best is trial 32 with value: -0.6692364534732137.
# Trial 40: AUC macro=0.66258, params={'n_estimators': 799, 'max_depth': 22, 'min_samples_split': 11, 'min_samples_leaf': 6, 'max_features': 0.4}
# [I 2025-06-21 05:12:54,982] Trial 41 finished with value: -0.6692479931877555 and parameters: {'n_estimators': 761, 'max_depth': 27, 'min_samples_split': 11, 'min_samples_leaf': 7, 'max_features': 'sqrt'}. Best is trial 41 with value: -0.6692479931877555.
# Trial 41: AUC macro=0.66925, params={'n_estimators': 761, 'max_depth': 27, 'min_samples_split': 11, 'min_samples_leaf': 7, 'max_features': 'sqrt'}
# [I 2025-06-21 05:17:46,638] Trial 42 finished with value: -0.6686241778125098 and parameters: {'n_estimators': 783, 'max_depth': 26, 'min_samples_split': 11, 'min_samples_leaf': 7, 'max_features': 'sqrt'}. Best is trial 41 with value: -0.6692479931877555.
# Trial 42: AUC macro=0.66862, params={'n_estimators': 783, 'max_depth': 26, 'min_samples_split': 11, 'min_samples_leaf': 7, 'max_features': 'sqrt'}
# [I 2025-06-21 05:19:49,250] Trial 43 finished with value: -0.6668207800076941 and parameters: {'n_estimators': 322, 'max_depth': 24, 'min_samples_split': 12, 'min_samples_leaf': 6, 'max_features': 'sqrt'}. Best is trial 41 with value: -0.6692479931877555.
# Trial 43: AUC macro=0.66682, params={'n_estimators': 322, 'max_depth': 24, 'min_samples_split': 12, 'min_samples_leaf': 6, 'max_features': 'sqrt'}
# [I 2025-06-21 05:27:39,684] Trial 44 finished with value: -0.6676722800427197 and parameters: {'n_estimators': 761, 'max_depth': 27, 'min_samples_split': 10, 'min_samples_leaf': 7, 'max_features': 0.1}. Best is trial 41 with value: -0.6692479931877555.
# Trial 44: AUC macro=0.66767, params={'n_estimators': 761, 'max_depth': 27, 'min_samples_split': 10, 'min_samples_leaf': 7, 'max_features': 0.1}
# [I 2025-06-21 05:41:34,819] Trial 45 finished with value: -0.665925030709529 and parameters: {'n_estimators': 726, 'max_depth': 28, 'min_samples_split': 11, 'min_samples_leaf': 9, 'max_features': 0.2}. Best is trial 41 with value: -0.6692479931877555.
# Trial 45: AUC macro=0.66593, params={'n_estimators': 726, 'max_depth': 28, 'min_samples_split': 11, 'min_samples_leaf': 9, 'max_features': 0.2}
# [I 2025-06-21 05:46:00,036] Trial 46 finished with value: -0.6690076803848984 and parameters: {'n_estimators': 690, 'max_depth': 26, 'min_samples_split': 12, 'min_samples_leaf': 5, 'max_features': 'sqrt'}. Best is trial 41 with value: -0.6692479931877555.
# Trial 46: AUC macro=0.66901, params={'n_estimators': 690, 'max_depth': 26, 'min_samples_split': 12, 'min_samples_leaf': 5, 'max_features': 'sqrt'}
# [I 2025-06-21 05:48:20,985] Trial 47 finished with value: -0.6661332777797752 and parameters: {'n_estimators': 776, 'max_depth': 14, 'min_samples_split': 9, 'min_samples_leaf': 7, 'max_features': 'log2'}. Best is trial 41 with value: -0.6692479931877555.
# Trial 47: AUC macro=0.66613, params={'n_estimators': 776, 'max_depth': 14, 'min_samples_split': 9, 'min_samples_leaf': 7, 'max_features': 'log2'}
# [I 2025-06-21 05:52:52,376] Trial 48 finished with value: -0.6687477842581311 and parameters: {'n_estimators': 718, 'max_depth': 24, 'min_samples_split': 10, 'min_samples_leaf': 6, 'max_features': 'sqrt'}. Best is trial 41 with value: -0.6692479931877555.
# Trial 48: AUC macro=0.66875, params={'n_estimators': 718, 'max_depth': 24, 'min_samples_split': 10, 'min_samples_leaf': 6, 'max_features': 'sqrt'}
# [I 2025-06-21 06:00:23,243] Trial 49 finished with value: -0.6679961158421887 and parameters: {'n_estimators': 691, 'max_depth': 26, 'min_samples_split': 11, 'min_samples_leaf': 4, 'max_features': 0.1}. Best is trial 41 with value: -0.6692479931877555.
# Trial 49: AUC macro=0.66800, params={'n_estimators': 691, 'max_depth': 26, 'min_samples_split': 11, 'min_samples_leaf': 4, 'max_features': 0.1}
# Best AUC macro (RandomForest): 0.6692479931877555
# Best params (RandomForest): {'n_estimators': 761, 'max_depth': 27, 'min_samples_split': 11, 'min_samples_leaf': 7, 'max_features': 'sqrt'}
